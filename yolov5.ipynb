# %%
# !git clone https://github.com/haonguyen1107/yolov5.git
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !pip install -qr requirements.txt

# %%
# from google.colab import drive 
# drive.mount('/content/gdrive')

# %%
# /content/gdrive/MyDrive/implant
import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.7.0+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
# !python train.py --data data/data.yaml --cfg models/yolov5s.yaml --weights runs/train/exp/weights/best.pt --batch-size 32 --epochs 50
# Out:
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 9 (delta 4), reused 9 (delta 4), pack-reused 0
# Unpacking objects: 100% (9/9), done.
# From https://github.com/haonguyen1107/yolov5
#    1a045ce..0cd3faa  main       -> origin/main
# fatal: ambiguous argument 'main..origin/master': unknown revision or path not in the working tree.
# Use '--' to separate paths from revisions, like this:
# 'git <command> [<revision>...] -- [<file>...]'
# github: Command 'git rev-list main..origin/master --count' returned non-zero exit status 128.
# YOLOv5 1a045ce torch 1.7.0+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# sua file implant.yaml
#/content/yolov5/runs/train/exp/weights/last.pt
# !python detect.py --source implant.jpg --weights runs/train/exp2/weights/last.pt --conf 0.25
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='implant.jpg', update=False, view_img=False, weights=['runs/train/exp2/weights/last.pt'])
# YOLOv5 1a045ce torch 1.7.0+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPS
# image 1/1 /content/yolov5/implant.jpg: 480x640 1 implant, Done. (0.013s)
# Results saved to runs/detect/exp3
# Done. (0.028s)

# %%
from utils.plots import plot_results 
plot_results(save_dir='runs/train/exp')  # plot all results*.txt as results.png
Image(filename='runs/train/exp/results.png', width=800)
